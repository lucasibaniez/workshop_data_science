# %% [markdown]
# # **Clase 3 - Pandas**

# %% [markdown]
# # **Qué es Pandas?**

# %% [markdown]
# Pandas es una librería de Python empleada principalmente para el análisis de datos con enfoque hacia la ciencia de datos e inteligencia artificial.

# %% [markdown]
# ## Carga de Librería

# %%
import pandas as pd
import numpy as np
import random

# %% [markdown]
# ## Conexión a Google Drive

# %%
# Montar Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Nos posicionamos en el directorio donde esta la tabla
# %cd "/content/drive/My Drive/Colab Notebooks/Capacitacion IA - ECOM/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/Capacitacion IA - ECOM

# %% [markdown]
# # **Dos Conceptos Fundamentales**

# %% [markdown]
# Pandas posee dos objetos principales, los cuales empleamos en conjunto para llevar a cabo nuestros análisis. Estos conceptos son los de **DataFrame** y **Series**.

# %% [markdown]
# ## DataFrames

# %% [markdown]
# En Pandas, los **DataFrames** son tablas. Esto significa que están formados por filas y columnas.

# %% [markdown]
# ### Forma
#
#
# Veamos a continuación un ejemplo de definición de un DataFrame.

# %%
# Creamos un DataFrame y lo asignamos a una variable
dataset = pd.DataFrame(
    {
        'Azul': [100, 43],
        'Rojo': [70, 12]
    }
)

# Visualizamos nuestro DataFrame
dataset
# Out:
#    Azul  Rojo
# 0   100    70
# 1    43    12

# %% [markdown]
# Como podemos ver, no solo se visualizan los datos que ingresamos para nuestro DataFrame, sino que además Pandas agregó automáticamente un índice autoincremental a nuestra tabla. En etapas posteriores veremos como podemos editar esta tabla.

# %% [markdown]
# ## Series

# %% [markdown]
# Si los DataFrames podemos tomarlos como tablas de varias filas y columnas, a las Series podemos considerarlas como tablas de múltiples filas con **una única columna**.

# %% [markdown]
# ### Forma

# %%
# Creamos una serie y la asignamos a una variable
single_dataset = pd.Series([random.randint(1, 999) for _ in range(10)])

# Visualizamos nuestra Serie
single_dataset
# Out:
# 0    208
# 1     21
# 2    850
# 3    676
# 4     44
# 5    952
# 6    975
# 7    220
# 8    597
# 9    503
# dtype: int64

# %% [markdown]
# Al igual que el caso anterior en DataFrame, Pandas agregó una columna de índice autoincremental a nuestros datos.

# %% [markdown]
# # **Operaciones en Pandas**

# %% [markdown]
# En las operaciones que se describen posteriormente, vamos a ver que algunos casos son aplicados sobre `DataFrames` y en otros casos son aplicados sobre `Series`. A su vez, ciertos procesamientos sobre `DataFrames` dan como resultado una `Serie`, como también es posible obtener un `DataFrame` mediante `Series`.
#
# El punto que debemos resaltar es que nunca vamos a estar trabajando exclusivamente sobre `DataFrames` o `Series`, sino que siempre vamosa tener una combinación de ambos.

# %% [markdown]
# ## Carga desde un archivo CSV

# %% [markdown]
# La gran mayoría de las veces no vamos a estar generando datos manualmente, sino que los vamos a cargar desde algún medio externo, ya sea una base de datos o algún archivo.
#
# Para la carga de un archivo CSV empleamos la funcion **read_csv** de un `DataFrame` de Pandas. A continuación se explican las partes de dicha función.

# %%
file = "MOCK_DATA.csv"

dataset = pd.read_csv(
    file,                       # Nombre o variable que contenga el archivo
    header=0,                   # Fila a emplear como nombre de columnas
    index_col=0,                # Columna a emplear como índice
    encoding='ISO-8859-1',      # El tipo de codificación a emplear para el parsing del archivo
    sep=',',                    # Caracter empleado para separar campos
    na_values=' ',              # Strings adicionales que se emplean para detectar datos NaN
    low_memory=False            # Si está en verdadero, el archivo se lee en partes. Esto puede producir errores de tipos de datos.
)

# %% [markdown]
# > En el caso que no quisieramos que `read_csv()` tome una fila como nombre de la columna, simplemente debemos asignar a `header=None`.

# %% [markdown]
# ## Forma del DataFrame

# %% [markdown]
# La forma del `DataFrame` nos muestra una tupla en donde se indica, ordenadamente, la cantidad de filas y columnas que posee.

# %%
dataset.shape
# Out:
# (1000, 11)

# %% [markdown]
# Si bien nuestro dataset posee 12 columnas, al realizar la carga del CSV definimos la columna de nuestro índice como la primer columna, que es exactamente la columna `id`.

# %% [markdown]
# ## Descripción del DataFrame

# %% [markdown]
# La descripción o información de un `DataFrame` nos brinda información detallada sobre los tipos de datos por los que están formadas cada columna, como así también la cantidad de datos no nulos que existen en ellas. Ésto último resulta muy importante a la hora de realizar la limpieza de datos ya que nos permite definir el método a seguir para el procesamiento de datos nulos.

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first_name    1000 non-null   object
#  1   last_name     1000 non-null   object
#  2   email         1000 non-null   object
#  3   country       1000 non-null   object
#  4   age           1000 non-null   int64
#  5   income        1000 non-null   object
#  6   is_employed   1000 non-null   bool
#  7   group_id      1000 non-null   int64
#  8   last_access   1000 non-null   object
#  9   last_updated  898 non-null    object
#  10  has_default   802 non-null    object
# dtypes: bool(1), int64(2), object(8)
# memory usage: 86.9+ KB

# %% [markdown]
# ## Visualización de un DataFrame

# %% [markdown]
# Para visualizar correctamente un `DataFrame`, y además permitir un mejor formato en Google Colab, empleamos la funcion **head**. Dicha función recibe como parámetro un número entero el cual indica la cantidad de filas que se deben mostrar. Si de lo contrario, la función es llamada sin un valor, entonces se muestran las cinco primeras filas del `DataFrame`.

# %%
dataset.head()
# Out:
#    first_name last_name                            email    country  age  \
# id
# 1   Christean    Guihen  cguihen0@nationalgeographic.com  Indonesia   53
# 2        Hill  Pettyfar            hpettyfar1@uol.com.br  Indonesia   18
# 3      Janine    Bleeze           jbleeze2@instagram.com      China   19
# 4      Marwin     Rowen            mrowen3@pinterest.com      China   88
# 5      Paulie    Gayler           pgayler4@moonfruit.com     Poland   55
#
#        income  is_employed  group_id           last_access  \
# id
# 1   $28441.86         True         2  1973-08-11T03:34:36Z
# 2   $10361.90        False         2  1986-09-19T13:06:02Z
# 3   $67932.75        False         4  1991-11-04T00:16:20Z
# 4   $17908.90         True         1  2010-08-27T14:18:47Z
# 5   $82084.73         True         1  1988-09-28T17:38:42Z
#
#             last_updated has_default
# id
# 1   2017-05-20T11:18:02Z       False
# 2   1984-11-04T06:22:22Z        True
# 3   1980-12-01T01:03:43Z        True
# 4   2017-10-13T19:27:40Z        True
# 5   1974-07-19T12:56:53Z        True

# %% [markdown]
# ## Modificación del Índice

# %%
# Modificamos el nombre del índice de id a ID
dataset.index.name = 'ID'

# Visualizamos el DataFrame
dataset.head()
# Out:
#    first_name last_name                            email    country  age  \
# ID
# 1   Christean    Guihen  cguihen0@nationalgeographic.com  Indonesia   53
# 2        Hill  Pettyfar            hpettyfar1@uol.com.br  Indonesia   18
# 3      Janine    Bleeze           jbleeze2@instagram.com      China   19
# 4      Marwin     Rowen            mrowen3@pinterest.com      China   88
# 5      Paulie    Gayler           pgayler4@moonfruit.com     Poland   55
#
#        income  is_employed  group_id           last_access  \
# ID
# 1   $28441.86         True         2  1973-08-11T03:34:36Z
# 2   $10361.90        False         2  1986-09-19T13:06:02Z
# 3   $67932.75        False         4  1991-11-04T00:16:20Z
# 4   $17908.90         True         1  2010-08-27T14:18:47Z
# 5   $82084.73         True         1  1988-09-28T17:38:42Z
#
#             last_updated has_default
# ID
# 1   2017-05-20T11:18:02Z       False
# 2   1984-11-04T06:22:22Z        True
# 3   1980-12-01T01:03:43Z        True
# 4   2017-10-13T19:27:40Z        True
# 5   1974-07-19T12:56:53Z        True

# %%
# Modificamos los valores del índice
index_values = {i: i*2 for i in range(dataset.shape[0])}

# Visualización del DataFrame
dataset.rename(index_values).head()
# Out:
#    first_name last_name                            email    country  age  \
# ID
# 2   Christean    Guihen  cguihen0@nationalgeographic.com  Indonesia   53
# 4        Hill  Pettyfar            hpettyfar1@uol.com.br  Indonesia   18
# 6      Janine    Bleeze           jbleeze2@instagram.com      China   19
# 8      Marwin     Rowen            mrowen3@pinterest.com      China   88
# 10     Paulie    Gayler           pgayler4@moonfruit.com     Poland   55
#
#        income  is_employed  group_id           last_access  \
# ID
# 2   $28441.86         True         2  1973-08-11T03:34:36Z
# 4   $10361.90        False         2  1986-09-19T13:06:02Z
# 6   $67932.75        False         4  1991-11-04T00:16:20Z
# 8   $17908.90         True         1  2010-08-27T14:18:47Z
# 10  $82084.73         True         1  1988-09-28T17:38:42Z
#
#             last_updated has_default
# ID
# 2   2017-05-20T11:18:02Z       False
# 4   1984-11-04T06:22:22Z        True
# 6   1980-12-01T01:03:43Z        True
# 8   2017-10-13T19:27:40Z        True
# 10  1974-07-19T12:56:53Z        True

# %% [markdown]
# ## Modificacion del Nombre de Columnas

# %%
# Renombramos las columnas empleando un mapping con diccionario
dataset.rename(columns={'group_id': 'category', 'has_default': 'is_retired'}, inplace=True)

# Visualizamos el DataFrame
dataset.head()
# Out:
#    first_name last_name                            email    country  age  \
# ID
# 1   Christean    Guihen  cguihen0@nationalgeographic.com  Indonesia   53
# 2        Hill  Pettyfar            hpettyfar1@uol.com.br  Indonesia   18
# 3      Janine    Bleeze           jbleeze2@instagram.com      China   19
# 4      Marwin     Rowen            mrowen3@pinterest.com      China   88
# 5      Paulie    Gayler           pgayler4@moonfruit.com     Poland   55
#
#        income  is_employed  category           last_access  \
# ID
# 1   $28441.86         True         2  1973-08-11T03:34:36Z
# 2   $10361.90        False         2  1986-09-19T13:06:02Z
# 3   $67932.75        False         4  1991-11-04T00:16:20Z
# 4   $17908.90         True         1  2010-08-27T14:18:47Z
# 5   $82084.73         True         1  1988-09-28T17:38:42Z
#
#             last_updated is_retired
# ID
# 1   2017-05-20T11:18:02Z      False
# 2   1984-11-04T06:22:22Z       True
# 3   1980-12-01T01:03:43Z       True
# 4   2017-10-13T19:27:40Z       True
# 5   1974-07-19T12:56:53Z       True

# %% [markdown]
# El parámetro **inplace** especifica si los cambios o procesamiento que debe realizarse producen cambios permanente al objeto. Éste parámetro se hace presente en múltiples funciones de Panda.

# %% [markdown]
# ## Indexación Simple

# %% [markdown]
# La indexación de `DataFrames` nos permite elegir una o un conjunto de columnas las cuales deseamos extraer del `DataFrame` para un posterior análisis.

# %%
# Obtenemos la columna 'country' mediante indexación
dataset['country']
# Out:
# ID
# 1       Indonesia
# 2       Indonesia
# 3           China
# 4           China
# 5          Poland
#           ...
# 996        Greece
# 997      Cambodia
# 998      Cameroon
# 999     Sri Lanka
# 1000       Sweden
# Name: country, Length: 1000, dtype: object

# %%
# Inspeccionamos el tipo de dato devuelto por la indexación
type(dataset['country'])
# Out:
# pandas.core.series.Series

# %%
# Realizamos indexación múltiple para obtener varias columnas
dataset[['age', 'income', 'is_retired']]
# Out:
#       age     income is_retired
# ID
# 1      53  $28441.86      False
# 2      18  $10361.90       True
# 3      19  $67932.75       True
# 4      88  $17908.90       True
# 5      55  $82084.73       True
# ...   ...        ...        ...
# 996    24  $17597.76       True
# 997    83   $4320.42      False
# 998    63  $83449.29      False
# 999    48  $26705.07      False
# 1000   76  $70339.65       True
#
# [1000 rows x 3 columns]

# %% [markdown]
# Para este caso de indexación múltiple, el resultado siempre será un nuevo DataFrame.

# %%
# Inspeccionamos el tipo de dato devuelto por la indexación múltiple
type(dataset[['age', 'income', 'is_retired']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Indexación de Pandas

# %% [markdown]
# Si bien es posible emplear una indexación simple como la vista anteriormente, Pandas ofrece su propios operadores de acceso los cuales son `loc` y `iloc`. Estos operadores son los que realmente deberíamos emplear al momento de realizar operaciones complejas.
#
# La gran diferencia entre el operador de acceso simple (visto anteriormente) y estos operadores, es que estos últimos siguen el orden de **(fila, columna)**.

# %% [markdown]
# ### Indexación con `iloc`

# %% [markdown]
# `iloc` refiere a una **selección basada en índices**. Esto quiere decir que `iloc` retorna datos ubicados en una posición numérica específica.
#
# Resulta importante resaltar que `iloc` emplea el exquema de indexación de `stdlib` de Python, lo que significa que los elementos dados en un rango siguen el patrón **[n inclusivo, n-1]**. Es decir que si quisieramos obtener los primeros 10 elementos haríamos [0, 10], lo cual se traduce a [0, 9].

# %%
# Obtenemos la tercer fila
dataset.iloc[2]
# Out:
# first_name                      Janine
# last_name                       Bleeze
# email           jbleeze2@instagram.com
# country                          China
# age                                 19
# income                       $67932.75
# is_employed                      False
# category                             4
# last_access       1991-11-04T00:16:20Z
# last_updated      1980-12-01T01:03:43Z
# is_retired                        True
# Name: 3, dtype: object

# %%
# Obtenemos de la décima fila hasta la décima-quinta fila
dataset.iloc[9:14]
# Out:
#    first_name    last_name                         email         country  age  \
# ID
# 10    Colleen      Stirman            cstirman9@wisc.edu           China   95
# 11    Marjory  Bickerstaff       mbickerstaffa@google.fr       Indonesia   40
# 12     Frasco   Chicchetto  fchicchettob@statcounter.com  Czech Republic   43
# 13      Jilli         Doag                jdoagc@who.int           China   28
# 14   Eberhard     O'Carran       eocarrand@sitemeter.com           China   69
#
#        income  is_employed  category           last_access  \
# ID
# 10   $3542.93        False         5  2003-08-16T22:24:58Z
# 11  $44665.55        False         5  1976-05-01T19:01:38Z
# 12  $79350.12        False         1  1967-08-29T08:25:45Z
# 13  $34839.88        False         1  1995-09-10T11:28:14Z
# 14  $26337.67        False         3  1981-01-05T18:36:54Z
#
#             last_updated is_retired
# ID
# 10  1989-10-25T13:51:12Z       True
# 11  1954-07-02T01:04:21Z       True
# 12  2016-08-15T20:56:56Z       True
# 13  2016-02-10T15:33:08Z      False
# 14  1964-08-25T01:21:31Z        NaN

# %%
# Obtenemos las tres primeras filas de la columna `country`
dataset.iloc[:3, 3]
# Out:
# ID
# 1    Indonesia
# 2    Indonesia
# 3        China
# Name: country, dtype: object

# %%
# Obtenemos la quinta, séptima y novena filas, con las columnas de `income` y `category`
dataset.iloc[[4, 6, 8], [5, 7]]
# Out:
#        income  category
# ID
# 5   $82084.73         1
# 7   $52687.11         4
# 9     $771.31         4

# %%
# Obtenemos las últimas 5 filas
dataset.iloc[-5:]
# Out:
#      first_name  last_name                    email    country  age  \
# ID
# 996    Ortensia    Cashell     ocashellrn@blogs.com     Greece   24
# 997      Lucine     MacBey       lmacbeyro@cnbc.com   Cambodia   83
# 998      Shanon     Brasse   sbrasserp@multiply.com   Cameroon   63
# 999      Marcus  Borrowman  mborrowmanrq@dyndns.org  Sri Lanka   48
# 1000     Harold   Willbond      hwillbondrr@cdc.gov     Sweden   76
#
#          income  is_employed  category           last_access  \
# ID
# 996   $17597.76        False         3  1991-06-14T21:16:53Z
# 997    $4320.42        False         3  1963-01-16T06:12:07Z
# 998   $83449.29         True         1  2010-05-25T11:13:59Z
# 999   $26705.07         True         3  2005-02-19T11:27:11Z
# 1000  $70339.65        False         3  1986-10-03T14:58:07Z
#
#               last_updated is_retired
# ID
# 996   1998-09-13T16:28:48Z       True
# 997   1991-02-01T18:58:27Z      False
# 998                    NaN      False
# 999   2011-03-03T17:47:30Z      False
# 1000  2001-08-09T09:32:13Z       True

# %% [markdown]
# ### Indexación con `loc`

# %% [markdown]
# A diferencia de `iloc`, `loc` refiere a una **selección basada en etiquetas**. Aquí lo que importa es el valor o dato que posee el índice y no su posición.

# %%
# Obtenemos la primer fila
dataset.loc[1]
# Out:
# first_name                            Christean
# last_name                                Guihen
# email           cguihen0@nationalgeographic.com
# country                               Indonesia
# age                                          53
# income                                $28441.86
# is_employed                                True
# category                                      2
# last_access                1973-08-11T03:34:36Z
# last_updated               2017-05-20T11:18:02Z
# is_retired                                False
# Name: 1, dtype: object

# %% [markdown]
# Como podemos ver, el comando anterior retorna la fila cuyo índice posee como valor el número 1. Recordando y diferenciando con iloc, que en cuyo caso anterior para obtener el primer elemento nos referíamos a la fila en la posición 0.
#
# Que pasaría ahora si quisieramos acceder a la primer fila empleando `loc` pero pensado como `iloc`? Para ello deberíamos pasar el valor 0 como parametro no?
#
# Veamos el siguiente ejemplo:

# %%
# Obtenemos la primer fila pensando con posiciones
dataset.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-1198480e0b8a> in <module>()
#       1 # Obtenemos la primer fila pensando con posiciones
# ----> 2 dataset.loc[0]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
# -> 1113         return self.obj.xs(label, axis=axis)
#    1114
#    1115     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3774                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3775         else:
# -> 3776             loc = index.get_loc(key)
#    3777
#    3778             if isinstance(loc, np.ndarray):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 0

# %% [markdown]
# Como podemos observar, obtenemos un error `KeyError` el cual nos demuestra que no existe en la columna índice una fila que contenga un ID igual a 0.

# %%
# Obtenemos todas las filas, en las columnas `country` e `income`
dataset.loc[:, ['country', 'income']]
# Out:
#         country     income
# ID
# 1     Indonesia  $28441.86
# 2     Indonesia  $10361.90
# 3         China  $67932.75
# 4         China  $17908.90
# 5        Poland  $82084.73
# ...         ...        ...
# 996      Greece  $17597.76
# 997    Cambodia   $4320.42
# 998    Cameroon  $83449.29
# 999   Sri Lanka  $26705.07
# 1000     Sweden  $70339.65
#
# [1000 rows x 2 columns]

# %%
# Obtenemos las filas con ID 90, 114 y 235, con las columnas `first_name` y `last_name`
dataset.loc[[90, 114, 235], ['first_name', 'last_name']]
# Out:
#     first_name last_name
# ID
# 90        Will   Bierman
# 114      Missy   Fretter
# 235      Arvin  Connechy

# %% [markdown]
# ## Selección Condicional

# %% [markdown]
# Además de poder realizar selección de datos basados en sus posiciones y/ o valor de índices, también es posible seleccionar datos empleando condiciones. Estas condiciones se resuelven principalmente retornando valores booleanos (verdadero o falso) de acuerdo a si el dato cumple o no con la condición de selección o búsqueda.

# %% [markdown]
# ### Selección Condicional Simple

# %%
# Obtenemos una lista con los países que cumplen la condición de ser Argentina
dataset['country'] == 'Argentina'
# Out:
# ID
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 996     False
# 997     False
# 998     False
# 999     False
# 1000    False
# Name: country, Length: 1000, dtype: bool

# %% [markdown]
# Como podemos observar para el caso anterior, el resultado de aplicar una selección condicional nos retorna una Serie en donde cada elemento es un resultado booleano de acuerdo a si la condición, definida anteriormente, se cumple o no.
#
# Para obtener finalmente la lista completa de aquellas filas que cumplen la condición de que `country` es igual a `Argentina` podemos emplear indexación con `loc`.

# %%
# Obteniendo el DataSet con aquellas filas que cumplen la condición anterior
dataset[dataset['country'] == 'Argentina']
# Out:
#      first_name   last_name                        email    country  age  \
# ID
# 215        Tess     Vockins   tvockins5y@marketwatch.com  Argentina   53
# 355        Jane      Risman         jrisman9u@dion.ne.jp  Argentina   80
# 491     Rolando    Kinchley          rkinchleydm@fda.gov  Argentina   41
# 537      Conway       Doick       cdoickew@artisteer.com  Argentina   26
# 570        Earl  MacDonough  emacdonoughft@google.com.hk  Argentina   67
# 595       Basia       Crane              bcranegi@wp.com  Argentina   40
# 715      Carley     Carayol       ccarayolju@cornell.edu  Argentina   58
# 765     Graehme       Peyto           gpeytol8@ocn.ne.jp  Argentina   63
# 921  Constancia      Pettus   cpettuspk@chronoengine.com  Argentina   87
# 961       Adina   Dunkerton   adunkertonqo@people.com.cn  Argentina   77
# 967      Chanda     Harriss      charrissqu@vkontakte.ru  Argentina   58
# 978        Fran   Fullstone    ffullstoner5@bluehost.com  Argentina   31
#
#         income  is_employed  category           last_access  \
# ID
# 215  $66705.77         True         3  2009-06-12T15:34:19Z
# 355  $67547.87         True         4  1951-08-18T09:54:32Z
# 491   $2397.92        False         5  2011-02-24T08:27:11Z
# 537  $33899.82        False         1  1964-07-09T13:28:32Z
# 570  $65210.98        False         2  1989-09-21T09:43:02Z
# 595  $66301.00         True         1  1953-07-12T10:18:12Z
# 715  $36094.37        False         1  2005-04-09T09:53:22Z
# 765  $35278.36        False         1  1970-11-02T05:09:12Z
# 921   $3190.31         True         3  1994-12-24T11:08:15Z
# 961  $13161.89         True         5  1979-10-08T15:36:27Z
# 967  $70789.78         True         1  1964-08-16T12:43:50Z
# 978  $30564.58         True         4  2007-01-27T10:15:19Z
#
#              last_updated is_retired
# ID
# 215  1986-08-14T02:23:49Z      False
# 355  1955-04-10T18:26:36Z      False
# 491  1977-09-07T13:43:05Z       True
# 537                   NaN      False
# 570                   NaN        NaN
# 595  1964-09-26T21:18:24Z        NaN
# 715  1969-03-14T21:12:11Z      False
# 765  1964-11-23T12:55:58Z       True
# 921  1953-03-08T02:30:15Z      False
# 961  1987-01-14T20:37:13Z       True
# 967  1990-01-21T20:04:18Z       True
# 978  1981-09-18T05:04:52Z       True

# %% [markdown]
# ### Selección Condicional Compuesta

# %% [markdown]
# La selección condicional puede extenderse aplicando múltiples condiciones a nuestro `DataFrame`. Veamos los siguientes ejemplos.

# %%
# Obtenemos un DataFrame en donde `age` sea mayor o igual a 25 y la `category` sea 3
dataset[(dataset['age'] >= 25) & (dataset['category'] == 3)]
# Out:
#      first_name  last_name                      email             country  \
# ID
# 6        Emelia   Tuckwood      etuckwood5@amazon.com  Dominican Republic
# 14     Eberhard   O'Carran    eocarrand@sitemeter.com               China
# 15     Shurlock    Marsham   smarshame@indiatimes.com           Indonesia
# 16        Roman     Hewins          rhewinsf@uiuc.edu             Uruguay
# 17       Adiana    Camelin   acameling@opensource.org               China
# ...         ...        ...                        ...                 ...
# 987      Isaiah      Abbys  iabbysre@chronoengine.com           Nicaragua
# 995    Thatcher      Ritch      tritchrm@vkontakte.ru               China
# 997      Lucine     MacBey         lmacbeyro@cnbc.com            Cambodia
# 999      Marcus  Borrowman    mborrowmanrq@dyndns.org           Sri Lanka
# 1000     Harold   Willbond        hwillbondrr@cdc.gov              Sweden
#
#       age     income  is_employed  category           last_access  \
# ID
# 6      43  $26159.26        False         3  1995-08-23T20:31:06Z
# 14     69  $26337.67        False         3  1981-01-05T18:36:54Z
# 15     40  $10332.09        False         3  1996-10-09T11:25:27Z
# 16     83  $77032.76         True         3  1998-05-11T23:40:00Z
# 17     81  $78555.56         True         3  1983-04-22T00:30:22Z
# ...   ...        ...          ...       ...                   ...
# 987    27  $73517.15         True         3  2003-08-02T18:40:09Z
# 995    58  $94615.05         True         3  1990-11-14T10:27:02Z
# 997    83   $4320.42        False         3  1963-01-16T06:12:07Z
# 999    48  $26705.07         True         3  2005-02-19T11:27:11Z
# 1000   76  $70339.65        False         3  1986-10-03T14:58:07Z
#
#               last_updated is_retired
# ID
# 6     1950-02-16T17:59:22Z        NaN
# 14    1964-08-25T01:21:31Z        NaN
# 15    1994-09-29T10:36:17Z      False
# 16    1962-12-26T08:29:58Z      False
# 17    1966-04-26T19:12:46Z        NaN
# ...                    ...        ...
# 987   2006-06-04T01:19:20Z       True
# 995   2000-06-10T22:50:13Z        NaN
# 997   1991-02-01T18:58:27Z      False
# 999   2011-03-03T17:47:30Z      False
# 1000  2001-08-09T09:32:13Z       True
#
# [186 rows x 11 columns]

# %% [markdown]
# Para las condiciones múltiples, los operadores condicionales de Python aplican normalmente. Estos operadores son:
#
#
# 1.   **&**: AND lógico
# 2.   **|**: OR lógico

# %% [markdown]
# ### Selección Condicional con Funciones incorporadas de Pandas

# %% [markdown]
# Además de poder aplicar condiciones manualmente sobre un `DataFrame`, Pandas ofrece algunas funciones ya incorporadas con las cuales podemos realizar selecciones condicionales. Veremos algunas de ellas a continuación.

# %%
# Emplamos `isin()` para obtener aquellas filas que cumplan con la condición de pertenencia
dataset.loc[dataset['country'].isin(['Germany', 'Sweden'])]
# Out:
#       first_name     last_name                            email  country  age  \
# ID
# 28        Coriss      Calderon  ccalderonr@pagesperso-orange.fr   Sweden   25
# 53         Marci       Bantick            mbantick1g@drupal.org   Sweden   58
# 90          Will       Bierman          wbierman2h@addtoany.com   Sweden   41
# 94        Garrot      Winslade            gwinslade2l@goo.ne.jp   Sweden   57
# 101      Wilfred   Ferencowicz         wferencowicz2s@prlog.org   Sweden   75
# 143       Allene       Haddick            ahaddick3y@tumblr.com   Sweden   94
# 195       Jeanna      O' Molan                jomolan5e@mail.ru   Sweden   54
# 209       Selene          Klas        sklas5s@ezinearticles.com   Sweden   94
# 210          Gal        Kidney               gkidney5t@xrea.com   Sweden   73
# 214       Andrei        Astlet             aastlet5x@joomla.org   Sweden   82
# 256        Brose       Elliman             belliman73@naver.com   Sweden   77
# 263     Jeanelle         Sever                  jsever7a@pen.io   Sweden   55
# 287       Darrin         Phear                   dphear7y@51.la   Sweden  100
# 327   Constantia        Scobie        cscobie92@ycombinator.com  Germany   91
# 342   Maximilian         Wigan               mwigan9h@google.es  Germany   56
# 362        Emlen        Praton             epratona1@utexas.edu   Sweden   33
# 387        Micki          Tire              mtireaq@cbsnews.com   Sweden   34
# 426      Adolphe        Hariot               ahariotbt@noaa.gov   Sweden   37
# 483      Humbert       Alloway                hallowayde@360.cn   Sweden   18
# 487        Minta          Elfe                 melfedi@yale.edu   Sweden   88
# 528         Haze        Bamell                 hbamellen@a8.net   Sweden   34
# 540      Celesta     Doddridge       cdoddridgeez@delicious.com   Sweden   19
# 562       Chicky      Fishwick        cfishwickfl@geocities.com   Sweden   83
# 568       Isiahi        Irdale        iirdalefr@bizjournals.com   Sweden   92
# 606    Marcellus    Novichenko     mnovichenkogt@mayoclinic.com   Sweden   37
# 616        Nicki      Cawkwell             ncawkwellh3@sohu.com   Sweden   58
# 676        Lewes       Dodgson               ldodgsonir@soup.io   Sweden   94
# 684       Tobias     Westbrook         twestbrookiz@cbsnews.com   Sweden   28
# 696        Malva       Wareham             mwarehamjb@amazon.de   Sweden   90
# 754       Lynett         Boick             lboickkx@tinypic.com  Germany   68
# 794     Petronia         Byrth      pbyrthm1@barnesandnoble.com   Sweden   41
# 826         Alie      Vedekhov     avedekhovmx@miitbeian.gov.cn   Sweden   34
# 855     Kamillah          Hare                kharenq@bbc.co.uk   Sweden   50
# 860        Belva      Brockway            bbrockwaynv@cisco.com   Sweden   45
# 868      Othelia  MacGilmartin      omacgilmartino3@cbsnews.com  Germany   42
# 881       Lorant        Cromly               lcromlyog@dell.com   Sweden   78
# 899    Pollyanna        Renton               prentonoy@sohu.com  Germany   60
# 980        Graig        Phelps           gphelpsr7@multiply.com   Sweden   81
# 1000      Harold      Willbond              hwillbondrr@cdc.gov   Sweden   76
#
#          income  is_employed  category           last_access  \
# ID
# 28    $87177.68         True         2  2004-11-17T23:13:33Z
# 53    $46776.85         True         1  1963-12-27T14:53:26Z
# 90    $28768.36        False         2  1954-11-01T10:21:31Z
# 94    $21626.22         True         4  2010-12-19T15:32:31Z
# 101   $10004.71         True         1  1985-09-08T20:02:57Z
# 143   $64785.03        False         3  2007-03-17T09:13:45Z
# 195   $18606.22        False         5  1956-09-01T04:50:36Z
# 209   $34454.58         True         2  1962-02-04T07:31:17Z
# 210   $40371.61        False         1  2020-06-14T16:27:49Z
# 214   $22898.48         True         4  2009-07-13T23:27:14Z
# 256   $10286.10         True         1  1966-09-24T23:50:03Z
# 263   $96149.46        False         5  1973-03-08T14:36:35Z
# 287    $8414.30         True         2  2010-07-31T06:04:35Z
# 327   $92081.62        False         5  1997-05-04T20:11:54Z
# 342   $71485.08         True         2  1968-02-16T00:21:15Z
# 362   $97719.82         True         2  1972-12-30T16:52:26Z
# 387   $34792.85        False         1  1994-10-29T02:37:23Z
# 426   $72036.87         True         3  1969-06-23T20:48:30Z
# 483   $90312.16        False         2  2011-07-21T05:29:44Z
# 487   $75042.53        False         4  1979-04-28T15:09:08Z
# 528   $17062.70         True         4  1988-01-28T03:47:30Z
# 540   $63041.42         True         1  2018-12-19T16:52:07Z
# 562   $52842.03         True         1  1997-04-09T18:51:45Z
# 568    $2691.85        False         5  1954-01-22T15:54:53Z
# 606   $89552.34        False         3  1961-10-07T03:41:24Z
# 616   $72760.30        False         4  1985-06-24T08:28:49Z
# 676   $19218.97         True         2  2021-11-23T22:31:12Z
# 684   $46275.30         True         1  1959-09-08T10:37:33Z
# 696   $98306.99        False         3  1957-10-08T13:57:28Z
# 754   $84973.93        False         2  1998-10-05T12:45:35Z
# 794    $9117.73        False         2  1956-11-05T01:33:33Z
# 826   $98625.20         True         2  1967-12-02T20:50:11Z
# 855   $34802.93        False         5  1997-02-23T12:49:40Z
# 860   $64026.61         True         1  1959-07-26T01:00:47Z
# 868    $1514.24        False         3  1986-11-26T08:32:04Z
# 881   $64231.88         True         4  2004-03-02T01:20:02Z
# 899   $50845.61        False         2  1964-01-02T12:31:36Z
# 980   $18255.09        False         2  1995-07-16T07:26:37Z
# 1000  $70339.65        False         3  1986-10-03T14:58:07Z
#
#               last_updated is_retired
# ID
# 28    1973-03-06T16:14:04Z       True
# 53    1976-03-25T16:55:03Z      False
# 90    2017-05-18T02:55:37Z      False
# 94    2005-11-26T18:27:10Z        NaN
# 101   1973-12-24T06:46:57Z      False
# 143   1962-05-06T15:58:05Z       True
# 195   1976-06-14T22:36:36Z      False
# 209   2000-01-31T02:55:55Z       True
# 210                    NaN      False
# 214   1971-03-30T13:11:50Z        NaN
# 256   1956-10-26T00:55:40Z        NaN
# 263   1982-03-03T16:44:25Z        NaN
# 287   2019-06-29T13:46:47Z      False
# 327   1959-01-19T20:05:19Z       True
# 342   1998-03-28T23:49:07Z       True
# 362   1981-09-30T15:42:39Z      False
# 387   1958-01-28T03:37:57Z       True
# 426   2017-08-02T08:46:01Z      False
# 483   2005-11-13T10:54:29Z       True
# 487                    NaN        NaN
# 528   1974-02-12T05:10:40Z      False
# 540   1980-01-16T05:23:38Z      False
# 562   2017-06-16T18:37:13Z      False
# 568                    NaN       True
# 606   2004-06-13T19:13:21Z       True
# 616   1975-09-06T09:54:50Z      False
# 676   1977-06-07T04:56:22Z       True
# 684   1988-01-10T00:18:02Z       True
# 696   1950-08-06T23:57:45Z       True
# 754   1972-07-16T09:27:54Z      False
# 794   1975-02-19T23:07:06Z      False
# 826   2021-01-31T05:57:14Z      False
# 855   1979-01-02T16:21:04Z      False
# 860   1964-09-09T10:25:40Z       True
# 868   2004-06-05T12:07:41Z      False
# 881   2007-04-15T18:11:05Z       True
# 899   1961-07-31T15:47:24Z        NaN
# 980   1994-07-21T02:40:34Z       True
# 1000  2001-08-09T09:32:13Z       True

# %%
# Emplamos `~` para negar `isin()` y obtener todas aquellas filas que no contengan la condición especificada
dataset.loc[~dataset['country'].isin(['China'])]
# Out:
#      first_name  last_name                            email  \
# ID
# 1     Christean     Guihen  cguihen0@nationalgeographic.com
# 2          Hill   Pettyfar            hpettyfar1@uol.com.br
# 5        Paulie     Gayler           pgayler4@moonfruit.com
# 6        Emelia   Tuckwood            etuckwood5@amazon.com
# 8         Thoma     Leathe               tleathe7@imgur.com
# ...         ...        ...                              ...
# 996    Ortensia    Cashell             ocashellrn@blogs.com
# 997      Lucine     MacBey               lmacbeyro@cnbc.com
# 998      Shanon     Brasse           sbrasserp@multiply.com
# 999      Marcus  Borrowman          mborrowmanrq@dyndns.org
# 1000     Harold   Willbond              hwillbondrr@cdc.gov
#
#                  country  age     income  is_employed  category  \
# ID
# 1              Indonesia   53  $28441.86         True         2
# 2              Indonesia   18  $10361.90        False         2
# 5                 Poland   55  $82084.73         True         1
# 6     Dominican Republic   43  $26159.26        False         3
# 8              Venezuela   48  $14267.30         True         2
# ...                  ...  ...        ...          ...       ...
# 996               Greece   24  $17597.76        False         3
# 997             Cambodia   83   $4320.42        False         3
# 998             Cameroon   63  $83449.29         True         1
# 999            Sri Lanka   48  $26705.07         True         3
# 1000              Sweden   76  $70339.65        False         3
#
#                last_access          last_updated is_retired
# ID
# 1     1973-08-11T03:34:36Z  2017-05-20T11:18:02Z      False
# 2     1986-09-19T13:06:02Z  1984-11-04T06:22:22Z       True
# 5     1988-09-28T17:38:42Z  1974-07-19T12:56:53Z       True
# 6     1995-08-23T20:31:06Z  1950-02-16T17:59:22Z        NaN
# 8     2008-06-26T00:30:53Z                   NaN      False
# ...                    ...                   ...        ...
# 996   1991-06-14T21:16:53Z  1998-09-13T16:28:48Z       True
# 997   1963-01-16T06:12:07Z  1991-02-01T18:58:27Z      False
# 998   2010-05-25T11:13:59Z                   NaN      False
# 999   2005-02-19T11:27:11Z  2011-03-03T17:47:30Z      False
# 1000  1986-10-03T14:58:07Z  2001-08-09T09:32:13Z       True
#
# [822 rows x 11 columns]

# %% [markdown]
# Como podemos observar, emplamos el símbolo `~` para denotar una negación a la función `isin()`, la cual la transformaría en `not_in()`, siendo que ésta última función no existe en Pandas pero igualmente es posible de realizarla gracias a los operadores lógicos.

# %%
# Empleamos `isnull()` para obtener aquellas filas que cumplen con la condición de poseer datos nulos en `last_updated`
dataset.loc[dataset['last_updated'].isnull()]
# Out:
#      first_name  last_name                       email    country  age  \
# ID
# 7         Celie    Beining      cbeining6@facebook.com      China   52
# 8         Thoma     Leathe          tleathe7@imgur.com  Venezuela   48
# 19      Lucille  Underwood         lunderwoodi@psu.edu      China   88
# 50      Creight    Rilings        crilings1d@google.de  Indonesia   91
# 71       Cedric    Kenaway        ckenaway1y@sogou.com      Syria   69
# ..          ...        ...                         ...        ...  ...
# 943       Rudie     Jirzik          rjirzikq6@cnet.com      China   39
# 962     Viviyan      Eynon      veynonqp@posterous.com   Colombia   91
# 964  Anna-diana       Izod           aizodqr@hc360.com     Canada   48
# 982         Mac  Dudleston  mdudlestonr9@angelfire.com  Indonesia   58
# 998      Shanon     Brasse      sbrasserp@multiply.com   Cameroon   63
#
#         income  is_employed  category           last_access last_updated  \
# ID
# 7    $52687.11         True         4  1962-07-09T06:43:24Z          NaN
# 8    $14267.30         True         2  2008-06-26T00:30:53Z          NaN
# 19   $94152.37        False         5  1993-09-08T00:25:07Z          NaN
# 50    $3519.66        False         4  1996-11-24T17:57:15Z          NaN
# 71   $89309.30         True         2  1957-02-25T00:39:32Z          NaN
# ..         ...          ...       ...                   ...          ...
# 943   $6401.31         True         4  2008-07-31T17:37:22Z          NaN
# 962  $78938.02        False         2  1979-06-19T22:37:17Z          NaN
# 964  $95290.56        False         2  1986-12-26T05:33:33Z          NaN
# 982   $5324.27         True         1  1993-10-23T19:06:41Z          NaN
# 998  $83449.29         True         1  2010-05-25T11:13:59Z          NaN
#
#     is_retired
# ID
# 7        False
# 8        False
# 19       False
# 50       False
# 71       False
# ..         ...
# 943       True
# 962      False
# 964        NaN
# 982       True
# 998      False
#
# [102 rows x 11 columns]

# %%
# Emplamos, de manera contraria al ejemplo anterior, `notnull()` para obtener aquellas filas en las cuales `last_updated` no es nulo
dataset.loc[dataset['last_updated'].notnull()]
# Out:
#      first_name  last_name                            email    country  age  \
# ID
# 1     Christean     Guihen  cguihen0@nationalgeographic.com  Indonesia   53
# 2          Hill   Pettyfar            hpettyfar1@uol.com.br  Indonesia   18
# 3        Janine     Bleeze           jbleeze2@instagram.com      China   19
# 4        Marwin      Rowen            mrowen3@pinterest.com      China   88
# 5        Paulie     Gayler           pgayler4@moonfruit.com     Poland   55
# ...         ...        ...                              ...        ...  ...
# 995    Thatcher      Ritch            tritchrm@vkontakte.ru      China   58
# 996    Ortensia    Cashell             ocashellrn@blogs.com     Greece   24
# 997      Lucine     MacBey               lmacbeyro@cnbc.com   Cambodia   83
# 999      Marcus  Borrowman          mborrowmanrq@dyndns.org  Sri Lanka   48
# 1000     Harold   Willbond              hwillbondrr@cdc.gov     Sweden   76
#
#          income  is_employed  category           last_access  \
# ID
# 1     $28441.86         True         2  1973-08-11T03:34:36Z
# 2     $10361.90        False         2  1986-09-19T13:06:02Z
# 3     $67932.75        False         4  1991-11-04T00:16:20Z
# 4     $17908.90         True         1  2010-08-27T14:18:47Z
# 5     $82084.73         True         1  1988-09-28T17:38:42Z
# ...         ...          ...       ...                   ...
# 995   $94615.05         True         3  1990-11-14T10:27:02Z
# 996   $17597.76        False         3  1991-06-14T21:16:53Z
# 997    $4320.42        False         3  1963-01-16T06:12:07Z
# 999   $26705.07         True         3  2005-02-19T11:27:11Z
# 1000  $70339.65        False         3  1986-10-03T14:58:07Z
#
#               last_updated is_retired
# ID
# 1     2017-05-20T11:18:02Z      False
# 2     1984-11-04T06:22:22Z       True
# 3     1980-12-01T01:03:43Z       True
# 4     2017-10-13T19:27:40Z       True
# 5     1974-07-19T12:56:53Z       True
# ...                    ...        ...
# 995   2000-06-10T22:50:13Z        NaN
# 996   1998-09-13T16:28:48Z       True
# 997   1991-02-01T18:58:27Z      False
# 999   2011-03-03T17:47:30Z      False
# 1000  2001-08-09T09:32:13Z       True
#
# [898 rows x 11 columns]

# %% [markdown]
# Resulta muy probable encontrarnos con implementaciones en las cuales en vez de emplear **isnull()** se usa **isna()**. En cuanto a Pandas se refiere, ambas funciones realizan exactamente el mismo proceso, el cual es detectar aquellas celdas que no posean valores o posean valores nulos. **isnull()** es en realidad un alias de **isna()** y es por esto que ambos poseen el mismo comportamiento.
#
# Esta diferenciación solo es en nombre. El porque de la existencia de ambos, se debe a que los `DataFrame` de Pandas están basados en los `DataFrame` de **R**, software empleado para la computación estadística. Allí, los datos NaN y Null son considerados distintos.

# %% [markdown]
# ## Funciones Sumatorias

# %% [markdown]
# Pandas nos ofrece un conjunto de funciones sumatorias las cuales nos facilitan ciertas operaciones sobre los datos. A continuación, veremos algunas de ellas.

# %% [markdown]
# ### Descripción de una Columna

# %% [markdown]
# Éste método nos ofrece un "resúmen" de una columna. Además, dicho método se adapta al tipo de dato que se esté trabajando.

# %%
# Emplamos `describe()` en una columna con elementos numéricos
dataset['age'].describe()
# Out:
# count    1000.000000
# mean       59.204000
# std        23.086389
# min        18.000000
# 25%        40.000000
# 50%        59.500000
# 75%        79.000000
# max       100.000000
# Name: age, dtype: float64

# %%
# Empleamos `describe()` en una columna con elementos alfanuméricos
dataset['country'].describe()
# Out:
# count      1000
# unique      114
# top       China
# freq        178
# Name: country, dtype: object

# %% [markdown]
# ### Sumatoria

# %%
# Sumatoria de una columna
dataset['age'].sum()
# Out:
# 59204

# %% [markdown]
# ### Media

# %%
# Media de una columna
dataset['age'].mean()
# Out:
# 59.204

# %% [markdown]
# ### Moda

# %%
# Moda de una columna
dataset['age'].mode()
# Out:
# 0    81
# dtype: int64

# %% [markdown]
# ### Elementos Únicos

# %%
# Elementos únicos en una columna
dataset['category'].unique()
# Out:
# array([2, 4, 1, 3, 5])

# %% [markdown]
# ### Cantidad de Elementos

# %%
# Obtenemos una lista de elementos únicos y cuantas veces se repiten
dataset['country'].value_counts()
# Out:
# China               178
# Indonesia           115
# Philippines          58
# Poland               49
# Russia               48
#                    ...
# Bahrain               1
# United Kingdom        1
# French Polynesia      1
# Bhutan                1
# Nicaragua             1
# Name: country, Length: 114, dtype: int64

# %% [markdown]
# ## Funciones de Mapeo

# %% [markdown]
# Las funciones de mapeo se emplean para poder crear o transformar datos en otros tipos de representaciones o aplicar un procesamiento específico.
#
# Resulta importante aclarar que, al momento de aplicar funicones de mapeo, es necesario considerar la complejidad que se está por aplicar. Una mala implementación de estas funciones puede llevar a que el procesamiento tome minutos en vez de segundos.

# %% [markdown]
# ### Función `map()`

# %% [markdown]
# La función `map()` se emplea únicamente a una `Series` y acepta como parámetro un diccionario, `Series` o una función.

# %%
# Empleamos `map()` con una función lambda para procesar la columna `income`.

# Como la colunma income posee el símbolo $ lo quitamos empleando un map()
dataset_income = dataset['income'].map(lambda x: x[1:])

# Convertimos el resultado a float
dataset_income = pd.to_numeric(dataset_income)

# Asignamos los datos numéricos a nuestro dataset
dataset['income'] = dataset_income

# Visualizamos nuestra Series
dataset_income.head()
# Out:
# ID
# 1    28441.86
# 2    10361.90
# 3    67932.75
# 4    17908.90
# 5    82084.73
# Name: income, dtype: float64

# %%
# Empleamos `map()` para reducir `income` dado porcentajes aleatorios
dataset_income.map(lambda x: x * random.random())
# Out:
# ID
# 1       13266.881405
# 2        2433.604053
# 3        2909.619972
# 4       14905.496708
# 5       30041.148798
#             ...
# 996     17137.416535
# 997      2696.710723
# 998     80160.509631
# 999     10146.826655
# 1000    16835.595575
# Name: income, Length: 1000, dtype: float64

# %% [markdown]
# ### Función `apply()`

# %% [markdown]
# Esta función es aplicable tanto a `Series` como `DataFrames` y la idea general es la de poder aplicar un procesamiento a filas completas.
#
# A diferencia de `map()`, `apply()` solo acepta una función como parámetro.

# %%
# Definimos una función que obtiene un `row` como parámetro de entrada y reduce en un porcentaje aleatorio el `income`
def reduce_income(row):
  row['income'] *= random.random()
  return row

# Empleamos `apply()` sobre nuestro DataFrame
dataset.apply(reduce_income, axis=1).head()
# Out:
#    first_name last_name                            email    country  age  \
# ID
# 1   Christean    Guihen  cguihen0@nationalgeographic.com  Indonesia   53
# 2        Hill  Pettyfar            hpettyfar1@uol.com.br  Indonesia   18
# 3      Janine    Bleeze           jbleeze2@instagram.com      China   19
# 4      Marwin     Rowen            mrowen3@pinterest.com      China   88
# 5      Paulie    Gayler           pgayler4@moonfruit.com     Poland   55
#
#           income  is_employed  category           last_access  \
# ID
# 1   23614.254472         True         2  1973-08-11T03:34:36Z
# 2    9881.200508        False         2  1986-09-19T13:06:02Z
# 3    5437.514510        False         4  1991-11-04T00:16:20Z
# 4    9457.855885         True         1  2010-08-27T14:18:47Z
# 5   69569.294519         True         1  1988-09-28T17:38:42Z
#
#             last_updated is_retired
# ID
# 1   2017-05-20T11:18:02Z      False
# 2   1984-11-04T06:22:22Z       True
# 3   1980-12-01T01:03:43Z       True
# 4   2017-10-13T19:27:40Z       True
# 5   1974-07-19T12:56:53Z       True

# %% [markdown]
# En el comando anterior podemos observar que, además de la llamada a la función `reduce_income`, existe otro parámetro llamdo `axis`. `axis` puede tomar dos valores, los cuales tienen los siguientes comportamientos:
#
# *   **`axis=0`**: Indica que un método o
# función debe aplicarse a cada columna.
# *   **`axis=1`**: Indica que un método o función debe aplicarse a cada fila.

# %% [markdown]
# Otro punto a tener en cuenta en cuanto se refiere a los llamados de funciones aplicadas en `apply()` es que las funciones pasadas como parámetros (en nuestro caso `reduce_income`) siempre son llamadas sin los paréntesis. Ésto se debe a que estamos pasando como parámetro la función en sí (lo que se conoce como un `callback` en Python) y no la resolución o resultado de una función.

# %% [markdown]
# ## Agrupamiento y Ordenamiento

# %% [markdown]
# Pandas nos ofrece herramientas con las cuales podemos agrupar y ordenar la información de manera mucho más específica. Veremos a continuación algunos ejemplos.

# %% [markdown]
# ### Agrupamiento Simple

# %%
# Agrupamos por `category`
dataset_category = dataset.groupby('category')

# Obtenemos total de `income` por `category`
dataset_category['income'].sum()
# Out:
# category
# 1     8901713.74
# 2     9532991.81
# 3    10460379.45
# 4    10085726.71
# 5     9707591.57
# Name: income, dtype: float64

# %%
# Obtenemos la media de `income` por cada `category`
dataset_category['income'].mean()
# Out:
# category
# 1    45885.122371
# 2    46730.352010
# 3    52564.720854
# 4    49439.836814
# 5    48781.867186
# Name: income, dtype: float64

# %% [markdown]
# ### Agrupamiento Múltiple

# %% [markdown]
# Además de poder realizar agrupamientos simples, Pandas nos permite realizar agrupamientos por múltiples columnas. Veamos los siguientes ejemplos.

# %%
# Ordenamos por `country` y `category`
dataset_country_category = dataset.groupby(['country', 'category'])

# Obtenemos un `DataFrame` con aquellas personas de mayor `income`, ordenados por `country` y `category`
dataset_country_category.apply(lambda df: df.loc[df['income'].idxmax()])
# Out:
#                       first_name  last_name                             email  \
# country     category
# Afghanistan 3            Antonin   Beastall       abeastallmw@paginegialle.it
#             5              Latia     Bertin               lbertinrh@salon.com
# Albania     2            Richard   Sorensen           rsorensenqy@plala.or.jp
#             3            Adelice     Jayume                  ajayumerb@va.gov
#             4               Jody   Osbiston  josbistoncf@networksolutions.com
# ...                          ...        ...                               ...
# Vietnam     4              Costa    Delgado              cdelgadod4@intel.com
#             5         Gabriellia      Jewer                 gjewera2@usda.gov
# Yemen       4             Saloma    Haining             shainingpl@rediff.com
#             5               Cale  Hatherill          chatherillnx@typepad.com
# Zimbabwe    3              Sandi     Wilton                  swiltoni9@ca.gov
#
#                           country  age    income  is_employed  category  \
# country     category
# Afghanistan 3         Afghanistan   41  95184.05         True         3
#             5         Afghanistan   40  80424.87        False         5
# Albania     2             Albania   34  48997.79         True         2
#             3             Albania   95  17901.95        False         3
#             4             Albania   70  98683.79        False         4
# ...                           ...  ...       ...          ...       ...
# Vietnam     4             Vietnam   64  79794.05        False         4
#             5             Vietnam   39  99665.41         True         5
# Yemen       4               Yemen   58  85903.03         True         4
#             5               Yemen   93  61165.23         True         5
# Zimbabwe    3            Zimbabwe   87  60381.59        False         3
#
#                                last_access          last_updated is_retired
# country     category
# Afghanistan 3         1992-10-04T14:42:23Z                   NaN        NaN
#             5         2018-07-03T23:49:57Z  1992-06-24T04:24:25Z       True
# Albania     2         1955-11-15T08:15:53Z  1986-11-26T20:36:57Z        NaN
#             3         1990-07-15T15:17:27Z  1959-10-22T20:47:35Z       True
#             4         1965-09-22T10:42:50Z  1999-09-08T12:10:47Z      False
# ...                                    ...                   ...        ...
# Vietnam     4         2021-02-17T07:19:44Z  1972-04-29T21:08:15Z       True
#             5         1951-10-31T04:18:13Z  1975-05-06T11:34:45Z      False
# Yemen       4         1951-08-11T11:49:36Z  1970-01-09T01:58:35Z       True
#             5         2007-01-23T14:40:03Z  2002-09-13T18:45:15Z      False
# Zimbabwe    3         1958-09-23T22:59:50Z  1989-08-05T12:48:56Z       True
#
# [291 rows x 11 columns]

# %% [markdown]
# La función `idxmax()` empleada en nuestro mapeo anterior, retorna el índice de las filas que cumplen con el máximo valor de algún dato dado. Como en nuestro ejemplo estamos aplicando `df['income'].idxmax()`, esto significa que estamos obteniendo los índicies de aquellas filas cuyos `income` sean los valores más altos.

# %% [markdown]
# ### Agrupamientos con Agregaciones

# %% [markdown]
# Además de realizar agrupamientos y aplicar funciones, podemos emplear un método de Pandas que nos permite realizar múltiples operaciones simultáneamente.

# %%
# Obtenemos un agrupamiento por `country`
dataset_country = dataset.groupby('country')

# Realizamos una agregación con múltiples funciones
dataset_country['income'].agg([min, max, np.mean])
# Out:
#                   min       max          mean
# country
# Afghanistan  45405.07  95184.05  72323.427500
# Albania      17901.95  98683.79  62457.062500
# Angola       43782.44  43782.44  43782.440000
# Argentina     2397.92  70789.78  40928.554167
# Armenia       7957.78  50882.36  27994.356000
# ...               ...       ...           ...
# Uzbekistan    3092.00   3092.00   3092.000000
# Venezuela     7080.79  91667.88  40140.973333
# Vietnam      11101.19  99665.41  60627.596000
# Yemen        61165.23  85903.03  73534.130000
# Zimbabwe     60381.59  60381.59  60381.590000
#
# [114 rows x 3 columns]

# %% [markdown]
# ### Ordenamiento

# %% [markdown]
# Otra funcionalidad de Pandas que resulta importante a la hora de realizar el análisis y procesamiento de datos, es la del ordenamiento de datos.

# %%
# Ordenamos por `age` ascendente
dataset['age'].sort_values()
# Out:
# ID
# 935     18
# 824     18
# 121     18
# 947     18
# 843     18
#       ...
# 879    100
# 287    100
# 828    100
# 956    100
# 458    100
# Name: age, Length: 1000, dtype: int64

# %%
# Ordenamos por `income` descendiente
dataset['income'].sort_values(ascending=False)
# Out:
# ID
# 278    99899.99
# 319    99884.45
# 797    99860.50
# 60     99685.56
# 363    99665.41
#          ...
# 574      700.24
# 224      591.93
# 526      391.68
# 832      167.90
# 717      123.07
# Name: income, Length: 1000, dtype: float64

# %%
# Ordenamos por múltiples columnas, de forma descendiente
dataset.sort_values(by=['country', 'category'], ascending=False)
# Out:
#      first_name   last_name                        email      country  age  \
# ID
# 658       Sandi      Wilton             swiltoni9@ca.gov     Zimbabwe   87
# 862        Cale   Hatherill     chatherillnx@typepad.com        Yemen   93
# 922      Saloma     Haining        shainingpl@rediff.com        Yemen   58
# 347      Allina  Reddlesden     areddlesden9m@forbes.com      Vietnam   33
# 363  Gabriellia       Jewer            gjewera2@usda.gov      Vietnam   39
# ..          ...         ...                          ...          ...  ...
# 971     Richard    Sorensen      rsorensenqy@plala.or.jp      Albania   34
# 154     Blinnie  Ligertwood        bligertwood49@home.pl  Afghanistan   87
# 867    Carmelia     Worters            cworterso2@go.com  Afghanistan   28
# 990       Latia      Bertin          lbertinrh@salon.com  Afghanistan   40
# 825     Antonin    Beastall  abeastallmw@paginegialle.it  Afghanistan   41
#
#        income  is_employed  category           last_access  \
# ID
# 658  60381.59        False         3  1958-09-23T22:59:50Z
# 862  61165.23         True         5  2007-01-23T14:40:03Z
# 922  85903.03         True         4  1951-08-11T11:49:36Z
# 347  65978.76        False         5  1973-11-03T15:34:43Z
# 363  99665.41         True         5  1951-10-31T04:18:13Z
# ..        ...          ...       ...                   ...
# 971  48997.79         True         2  1955-11-15T08:15:53Z
# 154  45405.07        False         5  1978-04-22T14:37:50Z
# 867  68279.72         True         5  2006-01-24T03:43:00Z
# 990  80424.87        False         5  2018-07-03T23:49:57Z
# 825  95184.05         True         3  1992-10-04T14:42:23Z
#
#              last_updated is_retired
# ID
# 658  1989-08-05T12:48:56Z       True
# 862  2002-09-13T18:45:15Z      False
# 922  1970-01-09T01:58:35Z       True
# 347  1986-04-18T09:28:31Z      False
# 363  1975-05-06T11:34:45Z      False
# ..                    ...        ...
# 971  1986-11-26T20:36:57Z        NaN
# 154  1954-12-01T17:18:49Z       True
# 867  1974-09-29T18:45:31Z        NaN
# 990  1992-06-24T04:24:25Z       True
# 825                   NaN        NaN
#
# [1000 rows x 11 columns]

# %% [markdown]
# ## Datos Faltantes

# %% [markdown]
# Al momento de realizar análisis de datos, es muy probable que nos encontremos con casos en donde ciertas columnas, que poseen datos significativos, contienen entradas faltantes.
#
# El análisis de como se deben tratar estos datos y como afecta al dataset en general dependerá pura y exclusivamente de lo que estemos analizando en todo su conjunto. Para este tipo de casos no existe una solución única.
#
# De todas formas, Pandas nos ofrece las herramientas para facilitarnos el tratamiento para estos casos.

# %% [markdown]
# ### Función `isnull()`

# %% [markdown]
# `isnull()` fue revisada anteriormente cuando vimos las `Selección Condicional`. Veamos nuevamente su aplicación a continuación.

# %%
# Obtenemos aquellas filas que poseen datos nulos en `is_retired`
dataset[pd.isnull(dataset['is_retired'])]
# Out:
#     first_name  last_name                     email             country  age  \
# ID
# 6       Emelia   Tuckwood     etuckwood5@amazon.com  Dominican Republic   43
# 14    Eberhard   O'Carran   eocarrand@sitemeter.com               China   69
# 17      Adiana    Camelin  acameling@opensource.org               China   81
# 34    Schuyler     Bolver        sbolverx@about.com         Philippines   79
# 46        Cash  McMarquis  cmcmarquis19@reuters.com              Poland   99
# ..         ...        ...                       ...                 ...  ...
# 968      Leora     Brandi        lbrandiqv@jugem.jp             Ireland   76
# 971    Richard   Sorensen   rsorensenqy@plala.or.jp             Albania   34
# 988       Ozzy   Monument    omonumentrf@unesco.org              Brazil   28
# 991    Janifer    Crossan     jcrossanri@paypal.com           Indonesia   98
# 995   Thatcher      Ritch     tritchrm@vkontakte.ru               China   58
#
#        income  is_employed  category           last_access  \
# ID
# 6    26159.26        False         3  1995-08-23T20:31:06Z
# 14   26337.67        False         3  1981-01-05T18:36:54Z
# 17   78555.56         True         3  1983-04-22T00:30:22Z
# 34    2690.59         True         2  2013-09-25T00:01:45Z
# 46   35643.46         True         3  1971-12-25T02:59:12Z
# ..        ...          ...       ...                   ...
# 968  49778.43        False         4  2000-10-03T19:03:27Z
# 971  48997.79         True         2  1955-11-15T08:15:53Z
# 988   3823.82        False         2  1986-11-27T09:02:55Z
# 991  88719.04         True         4  1962-08-10T23:10:01Z
# 995  94615.05         True         3  1990-11-14T10:27:02Z
#
#              last_updated is_retired
# ID
# 6    1950-02-16T17:59:22Z        NaN
# 14   1964-08-25T01:21:31Z        NaN
# 17   1966-04-26T19:12:46Z        NaN
# 34   1971-09-17T11:14:15Z        NaN
# 46   1965-07-31T21:39:57Z        NaN
# ..                    ...        ...
# 968  2007-05-12T00:27:18Z        NaN
# 971  1986-11-26T20:36:57Z        NaN
# 988  1953-07-27T00:00:11Z        NaN
# 991  1967-02-03T08:55:39Z        NaN
# 995  2000-06-10T22:50:13Z        NaN
#
# [198 rows x 11 columns]

# %% [markdown]
# Como podemos observar, obtuvimos todas las filas que poseen datos nulos en `is_retired`.
#
# Para poder trabajar con los datos, necesitamos poder cambiar estos datos nulos por otros datos no nulos. Que tipos de datos dependerá del análisis que se realizó sobre el dataset o el contexto del mismo.

# %% [markdown]
# Suponemos ahora que en la columna `is_retired` los datos booleanos que tenemos son los datos seguros de que una persona se encuentra o no retirada, y para ello éstas personas deberían haber presentado la documentación necesaria. Todas aquellas personas que no lo hicieron no podemos conocer su estado de retiro, por lo tanto en la base de datos se decidió por usar `NaN` como valor predeterminado.
#
# Dado éste análisis, como los datos `NaN` representan datos desconocidos procedemos a reemplazarlos por un string no nulo `Unknown`.

# %%
# Reemplazamos los datos `NaN` en `is_retired` por `Unknown`
dataset['is_retired'].fillna('Unknown', inplace=True)

# Visualizamos el dataset en `is_retired`
dataset[dataset['is_retired'] == 'Unknown']['is_retired']
# Out:
# ID
# 6      Unknown
# 14     Unknown
# 17     Unknown
# 34     Unknown
# 46     Unknown
#         ...
# 968    Unknown
# 971    Unknown
# 988    Unknown
# 991    Unknown
# 995    Unknown
# Name: is_retired, Length: 198, dtype: object

# %% [markdown]
# Como podemos observar, los datos `NaN` fueron reemplazados por `Unknown`.

# %% [markdown]
# ### Función `replace()`

# %% [markdown]
# Para los casos en donde los datos nulos no existan como tales, es decir, no son `NaN` sino un string representante como el caso anterior de `Unknown`, podemos emplear la función `replace()` para reemplazarlos, ya que `fillna()` no tendría ningún efecto para este caso.

# %%
# Reemplazamos los datos `Unknown` anteriores por `Missing`
dataset['is_retired'].replace(to_replace='Unknown', value='Missing', inplace=True)

# Visualizamos el dataset
dataset[dataset['is_retired'] == 'Missing']['is_retired']
# Out:
# ID
# 6      Missing
# 14     Missing
# 17     Missing
# 34     Missing
# 46     Missing
#         ...
# 968    Missing
# 971    Missing
# 988    Missing
# 991    Missing
# 995    Missing
# Name: is_retired, Length: 198, dtype: object

# %% [markdown]
# ## Unión de `DataFrames`

# %% [markdown]
# Durante el análisis de nuestros dataset, puede ocurrir que tengamos la necesidad de analizar varios datasets juntos. Por suerte, Pandas nos ofrece las funcionalidades exactas para poder realziar este tipo de uniones.

# %% [markdown]
# ### Función `concat()`

# %% [markdown]
# `concat()` es una de las uniones más sencillas. Dados dos `DataFrames`, `concat()` realiza una unión sencilla sin muchas opciones de control.

# %%
# Obtenemos las primeras 5 filas y las últimas 5 filas
dataset_first = dataset[:5]
dataset_last = dataset[-5:]

# Realizamos una union sencilla con `concat()`
dataset_final = pd.concat([dataset_first, dataset_last])

# Visualizamos el resultado
dataset_final.head(10)
# Out:
#      first_name  last_name                            email    country  age  \
# ID
# 1     Christean     Guihen  cguihen0@nationalgeographic.com  Indonesia   53
# 2          Hill   Pettyfar            hpettyfar1@uol.com.br  Indonesia   18
# 3        Janine     Bleeze           jbleeze2@instagram.com      China   19
# 4        Marwin      Rowen            mrowen3@pinterest.com      China   88
# 5        Paulie     Gayler           pgayler4@moonfruit.com     Poland   55
# 996    Ortensia    Cashell             ocashellrn@blogs.com     Greece   24
# 997      Lucine     MacBey               lmacbeyro@cnbc.com   Cambodia   83
# 998      Shanon     Brasse           sbrasserp@multiply.com   Cameroon   63
# 999      Marcus  Borrowman          mborrowmanrq@dyndns.org  Sri Lanka   48
# 1000     Harold   Willbond              hwillbondrr@cdc.gov     Sweden   76
#
#         income  is_employed  category           last_access  \
# ID
# 1     28441.86         True         2  1973-08-11T03:34:36Z
# 2     10361.90        False         2  1986-09-19T13:06:02Z
# 3     67932.75        False         4  1991-11-04T00:16:20Z
# 4     17908.90         True         1  2010-08-27T14:18:47Z
# 5     82084.73         True         1  1988-09-28T17:38:42Z
# 996   17597.76        False         3  1991-06-14T21:16:53Z
# 997    4320.42        False         3  1963-01-16T06:12:07Z
# 998   83449.29         True         1  2010-05-25T11:13:59Z
# 999   26705.07         True         3  2005-02-19T11:27:11Z
# 1000  70339.65        False         3  1986-10-03T14:58:07Z
#
#               last_updated is_retired
# ID
# 1     2017-05-20T11:18:02Z      False
# 2     1984-11-04T06:22:22Z       True
# 3     1980-12-01T01:03:43Z       True
# 4     2017-10-13T19:27:40Z       True
# 5     1974-07-19T12:56:53Z       True
# 996   1998-09-13T16:28:48Z       True
# 997   1991-02-01T18:58:27Z      False
# 998                    NaN      False
# 999   2011-03-03T17:47:30Z      False
# 1000  2001-08-09T09:32:13Z       True

# %% [markdown]
# `concat()` funciona mejor cuando ambos `DataFrames` poseen las mismas columnas.

# %% [markdown]
# ### Función `join()`

# %% [markdown]
# `join()` es un poco más compleja, pero a la vez mucho más capaz que `concat()`. Veamos un ejemplo.

# %%
# Emplando las dos definiciones anteriores, realizamos un `join()`
dataset_first.join(dataset_last, lsuffix='_LEFT', rsuffix='_RIGHT').head(10)
# Out:
#    first_name_LEFT last_name_LEFT                       email_LEFT  \
# ID
# 1        Christean         Guihen  cguihen0@nationalgeographic.com
# 2             Hill       Pettyfar            hpettyfar1@uol.com.br
# 3           Janine         Bleeze           jbleeze2@instagram.com
# 4           Marwin          Rowen            mrowen3@pinterest.com
# 5           Paulie         Gayler           pgayler4@moonfruit.com
#
#    country_LEFT  age_LEFT  income_LEFT  is_employed_LEFT  category_LEFT  \
# ID
# 1     Indonesia        53     28441.86              True              2
# 2     Indonesia        18     10361.90             False              2
# 3         China        19     67932.75             False              4
# 4         China        88     17908.90              True              1
# 5        Poland        55     82084.73              True              1
#
#         last_access_LEFT     last_updated_LEFT  ... last_name_RIGHT  \
# ID                                              ...
# 1   1973-08-11T03:34:36Z  2017-05-20T11:18:02Z  ...             NaN
# 2   1986-09-19T13:06:02Z  1984-11-04T06:22:22Z  ...             NaN
# 3   1991-11-04T00:16:20Z  1980-12-01T01:03:43Z  ...             NaN
# 4   2010-08-27T14:18:47Z  2017-10-13T19:27:40Z  ...             NaN
# 5   1988-09-28T17:38:42Z  1974-07-19T12:56:53Z  ...             NaN
#
#    email_RIGHT country_RIGHT age_RIGHT income_RIGHT  is_employed_RIGHT  \
# ID
# 1          NaN           NaN       NaN          NaN                NaN
# 2          NaN           NaN       NaN          NaN                NaN
# 3          NaN           NaN       NaN          NaN                NaN
# 4          NaN           NaN       NaN          NaN                NaN
# 5          NaN           NaN       NaN          NaN                NaN
#
#     category_RIGHT last_access_RIGHT  last_updated_RIGHT is_retired_RIGHT
# ID
# 1              NaN               NaN                 NaN              NaN
# 2              NaN               NaN                 NaN              NaN
# 3              NaN               NaN                 NaN              NaN
# 4              NaN               NaN                 NaN              NaN
# 5              NaN               NaN                 NaN              NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# Para el caso de `join()` se vuelve necesario definir los parámetros `lsuffix` y `rsuffix`. Como podemos ver, cada columna posee su sufijo de acuerdo a la condición de unión.
#
# Éste tipo de union nos sive si quisieramos realizar análisis en conjunto de dos o más datos específicos. Por ejemplo, realizar un `join()` de únicamente dos países.
#
# Veamos otro ejemplo.

# %%
# Obtenemos agregaciones de `age` e `income` de dos países
dataset_china = dataset[dataset['country'] == 'China'][['age', 'income']].agg([min, max, np.mean])
dataset_indonesia = dataset[dataset['country'] == 'Indonesia'][['age', 'income']].agg([min, max, np.mean])

# %%
# Unimos ambos emplando un `join()`
dataset_joined = dataset_china.join(dataset_indonesia, lsuffix='_CH', rsuffix='_IND')

dataset_joined
# Out:
#           age_CH     income_CH    age_IND    income_IND
# min    18.000000    591.930000  18.000000    391.680000
# max   100.000000  99860.500000  98.000000  99685.560000
# mean   60.679775  51017.717022  59.791304  49619.706435
